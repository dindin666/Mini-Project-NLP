# %% [markdown]
# <a href="https://colab.research.google.com/github/dindin666/Mini-Project-NLP/blob/main/Kelompok3_Enigma_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI Chatbot in Python

# %% [markdown]
# # **Anggota Kelompok 3 (Enigma) :**
# 1. Andjani Ayu Cahya Tanjung
# 2. Dina Amelia Alzahra
# 3. Hamdan Fauzaan
# 4. Mochammad Adjie Setyadji
# 5. Raihan Fakhri Rabbani
# 6. Yuke Salsabila

# %% [markdown]
# ---
# # AI Chatbot Versi Bahasa **Indonesia**
# # Proses 1 (Making Corpus with Download an Article)

# %%
# !pip install gtts

# %%
# !pip install newspaper3k

# %%
# Import library
from newspaper import Article
import random
import nltk
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import pandas as pd
import warnings
import re
warnings.filterwarnings('ignore')

from gtts import gTTS
import IPython.display as ipd
import time
from io import BytesIO

# %%
nltk.download('punkt', quiet=True)
# Out:
# True

# %%
import requests
import re

# %%
article = requests.get('https://raw.githubusercontent.com/dindin666/Mini-Project-NLP/main/nivearev.txt').text
corpus = article
print(corpus)
# Out:
# Nivea Body Lotion memiliki banyak varian yang bisa kamu sesuaikan dengan jenis dan kebutuhan kulitmu, Mulai dari untuk memberikan kelembapan ekstra, mencerahkan hingga jenis body serum dan sunblock pun ada, Agar kamu tidak bingung untuk memilihnya, langsung saja cek 10 varian Nivea Body Lotion untuk berbagai jenis dan kebutuhan kulitmu ini!
#
# 1. NIVEA Daily Protect Sun Lotion SPF33, melindungi kulit dari sinar matahari seharian
# Untuk melindungi kulit tubuh dari paparan sinar matahari sehari-hari, kamu bisa menggunakan NIVEA Daily Protect Sun Lotion SPF33 ini, Memakai produk ini secara teratur setiap hari akan bisa mengurangi efek negatif dari sinar matahari terhadap kulit tubuh sekaligus melembapkan kulit lebih dari 24 jam karena memiliki kandungan Hydra IQ, Perlindungan optimal dari sinar mataharinya bisa kamu dapatkan dari kandungan SPF33 lalu ada kandungan vitamin C sebagai antioksidan yang sangat bagus untuk melawan radikal bebas akibat paparan sinar UV dan polusi.
#
# ...

# %% [markdown]
# # Proses 2 (Tokenization)

# %%
# Tokenization
text = corpus
sentence_list = nltk.sent_tokenize(text) #A list of senetences

# Print the list of sentences
print(sentence_list)
# Out:
# ['Nivea Body Lotion memiliki banyak varian yang bisa kamu sesuaikan dengan jenis dan kebutuhan kulitmu, Mulai dari untuk memberikan kelembapan ekstra, mencerahkan hingga jenis body serum dan sunblock pun ada, Agar kamu tidak bingung untuk memilihnya, langsung saja cek 10 varian Nivea Body Lotion untuk berbagai jenis dan kebutuhan kulitmu ini!', '1.', 'NIVEA Daily Protect Sun Lotion SPF33, melindungi kulit dari sinar matahari seharian\r\nUntuk melindungi kulit tubuh dari paparan sinar matahari sehari-hari, kamu bisa menggunakan NIVEA Daily Protect Sun Lotion SPF33 ini, Memakai produk ini secara teratur setiap hari akan bisa mengurangi efek negatif dari sinar matahari terhadap kulit tubuh sekaligus melembapkan kulit lebih dari 24 jam karena memiliki kandungan Hydra IQ, Perlindungan optimal dari sinar mataharinya bisa kamu dapatkan dari kandungan SPF33 lalu ada kandungan vitamin C sebagai antioksidan yang sangat bagus untuk melawan radikal bebas akibat paparan sinar UV dan polusi.', '2.
# ...

# %%
#a function to return a random greeting response to a users greeting
def greeting_response(text):
    text = text.lower()
    
    #Bots greeting respone
    bot_greetings = ['Halo, chatbotnya sudah aktif!\n\n']
    
    #Users greeting
    user_greetings = ['p', 'hy', 'test', 'hai', 'halo', 'eh']
    for word in text.split():
        if word in user_greetings:
            return random.choice(bot_greetings)
        
    #Random response to greeting
    def gratitude_response(text):
        text=text.lower()

# %%
 def index_sort(list_var):
    length = len(list_var)
    list_index = list(range(0, length))
    
    x = list_var        
    for i in range(length):
        for j in range(length):
            if x[list_index[i]] > x[list_index[j]]:
                #swap
                temp = list_index[i]
                list_index[i] = list_index[j]
                list_index[j] = temp
                
    return list_index

# %%
# Creat Bots Response
def bot_response(user_input):
    user_input=user_input.lower()
    sentence_list.append(user_input)
    bot_response= ''
    cm=CountVectorizer().fit_transform(sentence_list)
    similarity_scores=cosine_similarity(cm[-1],cm)
    similarity_scores_list=similarity_scores.flatten()
    index=index_sort(similarity_scores_list)
    index=index[1:]
    response_flag=0
    
    j=0
    for i in range(len(index)):
        if similarity_scores_list[index[i]]>0.0:
            bot_response=bot_response+' '+sentence_list[index[i]]
            response_flag=1
            j=j+1
        if j>2:
            break

        if response_flag==0:
            bot_response=bot_response+" "+"Maaf, saya tidak mengerti"

        sentence_list.remove(user_input) 

        return bot_response

# %% [markdown]
# # Proses 4 (End Process, Making chat box)

# %%
#Start Chat
print("Ketik 'p, hy, test, hai, halo, atau eh' untuk mengaktifkan chatbot")
print('Kamu mau nanyain produk Vaseline yang mana?')
print('1. NIVEA Daily Protect Sun Lotion SPF33')
print('2. Nivea Intensive Moisture Body Lotion')
print('3. Nivea Sensational Body Lotion')
print('4. Nivea Extra White Instant Glow')
print('5. Nivea Extra White Firm & Smooth')
print('6. Nivea Extra White Body Serum Anti-Age')
print('7. Nivea Extra White Radiant & Smooth Body Cream')
print('8. Nivea Extra White Body Serum Hijab Cooling')
print('9. Nivea Extra White Repair & Protect')
print('10. Nivea Extra White Night Nourish')
print('11. Nivea Intensive Moisture Body Serum 48 jam')

exit_list=['exit','bye','keluar','quit', 'sampai jumpa', 'dah']

while(True):
    user_input=input()
    if user_input.lower() in exit_list:
        print('Doc Bot: Sampai jumpa lagi')
        tts = gTTS('Sampai jumpa lagi', lang='id')
        tts.save('mantap2.wav')
        time.sleep(0.08)
        print("Kamu:\n")
        ipd.display(ipd.Audio('mantap2.wav', autoplay=True))
            
        print("="*60 + "\n")
        break
    else:
        if greeting_response(user_input)!= None:
            print('Doc Bot: '+ greeting_response(user_input))
            tts = gTTS(greeting_response(user_input), lang='id')
            tts.save('mantap1.wav')
            time.sleep(0.08)
            print("Kamu:\n")
            ipd.display(ipd.Audio('mantap1.wav', autoplay=True))
            
            print("="*60 + "\n")
        else:
            print('Doc Bot: '+ bot_response(user_input))
            tts = gTTS(bot_response(user_input), lang='id')
            tts.save('mantap.wav')
            time.sleep(1)
            print("Kamu:\n")
            ipd.display(ipd.Audio('mantap.wav', autoplay=True))
            
            print("="*60 + "\n")
# Out:
# Ketik 'p, hy, test, hai, halo, atau eh' untuk mengaktifkan chatbot
# Kamu mau nanyain produk Vaseline yang mana?
# 1. NIVEA Daily Protect Sun Lotion SPF33
# 2. Nivea Intensive Moisture Body Lotion
# 3. Nivea Sensational Body Lotion
# 4. Nivea Extra White Instant Glow
# 5. Nivea Extra White Firm & Smooth
# 6. Nivea Extra White Body Serum Anti-Age
# 7. Nivea Extra White Radiant & Smooth Body Cream
# 8. Nivea Extra White Body Serum Hijab Cooling
# 9. Nivea Extra White Repair & Protect
# 10. Nivea Extra White Night Nourish
# 11. Nivea Intensive Moisture Body Serum 48 jam
# p
# Doc Bot: Halo, chatbotnya sudah aktif!
#
#
# Kamu:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ...
#
# sinar matahari
# Doc Bot:  NIVEA Daily Protect Sun Lotion SPF33, melindungi kulit dari sinar matahari seharian
# ...
